# %%
import pandas as pd
import numpy as np
print("hello")
# Out:
# hello

# %%
data = pd.read_csv('loan_risk_assessment_updated.csv')
df = pd.DataFrame(data) 
df.describe()
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Loan_ID                  1000 non-null   object
#  1   Age                      1000 non-null   int64
#  2   Income                   1000 non-null   int64
#  3   Employment_Length        1000 non-null   int64
#  4   Education_Level          1000 non-null   object
#  5   Marital_Status           1000 non-null   object
#  6   Loan_Amount              1000 non-null   int64
#  7   Loan_Term                1000 non-null   int64
#  8   Interest_Rate            1000 non-null   float64
#  9   Loan_Purpose             1000 non-null   object
#  10  Credit_Score             1000 non-null   int64
#  11  Debt_to_Income_Ratio     1000 non-null   float64
#  12  Number_of_Credit_Cards   1000 non-null   int64
#  13  Current_Total_Debt       1000 non-null   int64
# ...
